# %% [markdown]
# (In order to load the stylesheet of this notebook, execute the last code cell in this notebook)

# %% [markdown]
# # Clustering food recipes from around the world

# %% [markdown]
# In this assignment, you are expected to hierarchically cluster food recipes. We will be using YY Ahn's dataset "[Recipe datasets with cuisines](http://yongyeol.com/data/scirep-cuisines-detail.zip)", which for each recipe provides a list of ingredients and the country of origin, scraped from popular recipe websites. He also provides an [ingredient and compounds dataset](http://yongyeol.com/data/ingr_comp.zip), which you could potentially also make use of, if you find it interesting.
#
# You will be graded as follow:
# * Data parsing and representation **(20 pts)**
# * Clustering **(30 pts)**
# * Visualization **(30 pts)**
# * Short (datailed) analysis of specific cluster **(20 pts)**
#
# ---------------------------

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.cluster.vq import kmeans, kmeans2, whiten, vq
from scipy.spatial.distance import cdist
import sklearn.datasets as sk_data
import sklearn.metrics as metrics
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import set

# %%
#Converted the allr_recipes.txt file into a csv file.
recipes = pd.read_csv('../Homework-4/allr_recipes.csv')
print recipes
# Out:
#       Country             Ingredient_1       Ingredient_2   Ingredient_3  \
# 0      Canada                      egg              yeast          wheat
# 1      Canada                     pork             carrot            pea
# 2      Canada              maple_syrup                NaN            NaN
# 3      Canada                    wheat              yeast         almond
# 4      Canada                   butter             lovage           clam
# 5      Canada            cane_molasses             butter          wheat
# 6      Canada                asparagus          olive_oil         pepper
# 7      Canada                   butter           cilantro            tea
# 8      Canada            vegetable_oil              wheat            egg
# 9      Canada              lemon_juice              onion      soy_sauce
# 10     Canada                   butter      cane_molasses          wheat
# 11     Canada                   butter          olive_oil         pepper
# ...

# %%
df = pd.DataFrame(data = recipes)
df
# Out:
#       Country             Ingredient_1       Ingredient_2   Ingredient_3  \
# 0      Canada                      egg              yeast          wheat
# 1      Canada                     pork             carrot            pea
# 2      Canada              maple_syrup                NaN            NaN
# 3      Canada                    wheat              yeast         almond
# 4      Canada                   butter             lovage           clam
# 5      Canada            cane_molasses             butter          wheat
# 6      Canada                asparagus          olive_oil         pepper
# 7      Canada                   butter           cilantro            tea
# 8      Canada            vegetable_oil              wheat            egg
# 9      Canada              lemon_juice              onion      soy_sauce
# 10     Canada                   butter      cane_molasses          wheat
# 11     Canada                   butter          olive_oil         pepper
# ...

# %%
data_list = []
food_count = []
country = []
# for countr,case_title in recipes.groupby("Country"):
#     print(countr)
#     for recipe ,case_title in recipes.groupby("Ingredient 1"):
#         print(recipe)
print(df["Ingredient_1"])
# y = []
# for x in df["Country"] :
#     if x == "Canada":
#         y.append(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-18b72c3cd635> in <module>()
#       6 #     for recipe ,case_title in recipes.groupby("Ingredient 1"):
#       7 #         print(recipe)
# ----> 8 print(df["Ingredient_1"])
#       9 # y = []
#      10 # for x in df["Country"] :
#
# NameError: name 'df' is not defined

# %%
#df.dtypes

from itertools import groupby
cases={}
for case_title,case_data in recipes.groupby("Ingredient_1"):
    cases[case_title]=case_data.Country.count()
    print case_title, ":", cases[case_title]
# Out:
# almond : 45
# angelica : 1
# anise : 5
# anise_seed : 1
# apple : 131
# apple_brandy : 2
# apricot : 56
# artichoke : 3
# asparagus : 47
# avocado : 14
# bacon : 55
# baked_potato : 1
# banana : 13
# bartlett_pear : 1
# basil : 41
# bean : 33
# beef : 118
# beef_broth : 6
# beef_liver : 1
# beer : 18
# beet : 5
# bell_pepper : 3
# berry : 4
# bitter_orange : 1
# black_bean : 9
# black_currant : 1
# black_mustard_seed_oil : 5
# black_pepper : 47
# black_raspberry : 2
# black_tea : 4
# blackberry : 3
# blackberry_brandy : 1
# blue_cheese : 2
# blueberry : 4
# bourbon_whiskey : 29
# brandy : 9
# brassica : 2
# bread : 11
# broccoli : 1
# brown_rice : 3
# brussels_sprout : 3
# butter : 14213
# buttermilk : 63
# cabbage : 18
# cacao : 2
# camembert_cheese : 1
# cane_molasses : 3524
# caraway : 19
# cardamom : 38
# carrot : 6
# cashew : 2
# cauliflower : 13
# caviar : 3
# cayenne : 69
# celery : 83
# celery_oil : 2
# champagne_wine : 27
# cheddar_cheese : 59
# cheese : 554
# cherry : 117
# ...

# %%
from collections import Counter


x = recipes[recipes.Country == "Canada"]
y = recipes[recipes.Country != ""]

columns = []
dict1 = {}
countries = []


print(countries)


df2 = pd.DataFrame(data = x)
df3 = pd.DataFrame(data = y)

for n in range(41824):
    if(df3["Country"][n]) not in countries:
        countries.append(df3["Country"][n])

countries = sorted(countries)
#print(x)
#print len(x.Ingredient_1)

for y in range(1,34):
    columns.append("Ingredient_%s"%(y))  
food = []

for country_name in countries:
    for z in columns:
        for y in range(774):
            food.append((df2[z][y]))
            
    
    food = [x for x in food if str(x)!= "nan"]
    a = Counter(food)
    dict1[country_name] = a

    
#Will return all ingredients used in American recipes with their respective number of occurences
print(dict1['American'])    

# For example, wheat shows up in American recipes 306 times. 

print(dict1['American']['wheat'])


#print food_nodupes
#print countries_list


#print(dict1)
# Out:
# []
# ...

# %%
food_list = sorted(list(set(food)))
countries_list = list(set(countries))
final_list = []
final_dict = {}
print(dict1[country][food_list[0]])

for x in range(len(food_list)):
    country = 'American'
    final_dict[food_list[x]] = (dict1[country][food_list[x]])
    final_list.append(dict1[country][food_list[x]])
  
print final_dict
# Out:
# 28
# ...

# %%
# This graph shows the occurences of each ingredient for American food recipes

plt.bar(range(len(final_dict)), final_dict.values())
plt.xticks(range(len(final_dict)), final_dict.keys())

plt.show()

# %% [markdown]
# ### References

# %% [markdown]
# 1. Ahn, Yong-Yeol, et al. "Flavor network and the principles of food pairing." Scientific reports 1 (2011).

# %%
# Code for setting the style of the notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../../theme/custom.css", "r").read()
    return HTML(styles)
css_styling()
